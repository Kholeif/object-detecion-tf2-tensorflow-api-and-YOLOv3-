# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/tf2 object detection/models/research"
# Out:
# /content/drive/MyDrive/tf2 object detection/models/research

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard
# %tensorboard --logdir="/content/drive/MyDrive/tf2 object detection/training_process/train"

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip -o ngrok-stable-linux-amd64.zip

#the logs that are created while training 
LOG_DIR = "/content/drive/MyDrive/tf2 object detection/training_process/train"
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR)
)
get_ipython().system_raw('./ngrok http 6006 &')
#The link to tensorboard.
#works after the training starts.
# !curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# --2021-02-27 06:20:04--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 3.211.152.205, 34.195.37.70, 35.171.215.128, ...
# Connecting to bin.equinox.io (bin.equinox.io)|3.211.152.205|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13773305 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip.4’
#
# ngrok-stable-linux- 100%[===================>]  13.13M  17.2MB/s    in 0.8s
#
# 2021-02-27 06:20:05 (17.2 MB/s) - ‘ngrok-stable-linux-amd64.zip.4’ saved [13773305/13773305]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok
# https://0501f0c34da1.ngrok.io
